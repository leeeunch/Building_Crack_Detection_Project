# %% [markdown]
# # 드라이브 연결 및 데이터 불러오기

# %% [markdown]
# ## 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 데이터 불러오기

# %%
from glob import glob
# %cd /
img_list = glob('/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/images/*.jpg')
len(img_list)
# Out:
# /
# 1065

# %% [markdown]
# # train-test-validation set split

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/images/

img = glob('*.jpg')

# %cd ../labels
txt = glob('*.txt')

len(img), len(txt)
# Out:
# /content/drive/.shortcut-targets-by-id/1x9dqzQ3wqGKi02DVG-o0wpLtqF524nAw/Crack_Detector/crack_1000/images
# /content/drive/.shortcut-targets-by-id/1x9dqzQ3wqGKi02DVG-o0wpLtqF524nAw/Crack_Detector/crack_1000/labels
# (1065, 1065)

# %%
from sklearn.model_selection import train_test_split
train_img_list, test_img_list=train_test_split(img_list,test_size=0.2,random_state=2000)
print(len(train_img_list),len(test_img_list))
# Out:
# 852 213

# %%
train_img_list, val_img_list=train_test_split(train_img_list,test_size=0.2,random_state=2000)
print(len(train_img_list),len(val_img_list))
# Out:
# 681 171

# %%
len(train_img_list), len(test_img_list), len(val_img_list)
# Out:
# (681, 213, 171)

# %%
# %cd /
# %cd /content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000
with open('train.txt','w') as f:
  f.write('\n'.join(train_img_list)+ '\n')

with open('test.txt','w') as f:
  f.write('\n'.join(test_img_list)+ '\n')

with open('val.txt','w') as f:
  f.write('\n'.join(val_img_list)+ '\n')
# Out:
# /
# /content/drive/.shortcut-targets-by-id/1x9dqzQ3wqGKi02DVG-o0wpLtqF524nAw/Crack_Detector/crack_1000

# %%
#  Check all files is existed in the txt files
from os.path import exists
import os
import cv2
print(os.system('pwd'))
os.system('cd /')
train_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/train.txt'
image_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/image'
label_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/label'
with open(train_path) as f:
    train_lines = f.readlines()
print(len(train_lines))
val_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/val.txt'
image_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/image'
label_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/label'
with open(val_path) as f:
    val_lines = f.readlines()
print(len(val_lines))
test_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/test.txt'
image_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/image'
label_path = '/content/drive/MyDrive/Colab_Notebooks/ai_school/first_project/crack_dector/project_data/Crack_dectector/crack_1000/label'
with open(test_path) as f:
    test_lines = f.readlines()
print(len(test_lines))
# Out:
# 0
# 681
# 171
# 213

# %% [markdown]
# # wandb 로그인

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 4.4 MB/s
#      |████████████████████████████████| 181 kB 54.1 MB/s
#      |████████████████████████████████| 122 kB 58.1 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#      |████████████████████████████████| 157 kB 71.9 MB/s
#      |████████████████████████████████| 157 kB 70.4 MB/s
#      |████████████████████████████████| 157 kB 72.2 MB/s
#      |████████████████████████████████| 157 kB 74.1 MB/s
#      |████████████████████████████████| 157 kB 73.2 MB/s
#      |████████████████████████████████| 156 kB 62.5 MB/s
# ...
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # 훈련

# %%
import os
# %cd /

os.system('cd /')
# !python /content/drive/MyDrive/yolov5/train.py --img 416 --batch 16 --epochs 50 --data /content/drive/MyDrive/yolov5/chun_crack.yaml --cfg /content/drive/MyDrive/yolov5/models/yolov5l.yaml --weights /content/drive/MyDrive/yolov5/yolov5l-cls.pt --name crack_yolov5l_results
# Out:
# /
# train: weights=/content/drive/MyDrive/yolov5/yolov5l-cls.pt, cfg=/content/drive/MyDrive/yolov5/models/yolov5l.yaml, data=/content/drive/MyDrive/yolov5/chun_crack.yaml, hyp=content/drive/MyDrive/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=content/drive/MyDrive/yolov5/runs/train, name=crack_yolov5l_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# requirements: ipython not found and is required by YOLOv5, attempting auto-update...
# ...

# %% [markdown]
# # 검증

# %%
# %cd /
# !python content/drive/MyDrive/yolov5/val.py --weights content/drive/MyDrive/yolov5/runs/train/crack_yolov5l_results4/weights/best.pt --data /content/drive/MyDrive/yolov5/chun_crack.yaml --img 640 --iou 0.65 --half

# %% [markdown]
# # 테스트

# %%
# !python content/drive/MyDrive/yolov5/val.py --weights content/drive/MyDrive/yolov5/runs/train/crack_yolov5l_results4/weights/best.pt --data /content/drive/MyDrive/yolov5/chun_crack.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 영상에 모델 학습

# %%
# %cd /
# !python /content/drive/MyDrive/yolov5/detect.py --source /content/drive/MyDrive/crack_video/KakaoTalk_20220903_184107179.mp4 --weights /content/drive/MyDrive/yolov5/runs/train/crack_yolov5l_results4/weights/best.pt --conf 0.5
# Out:
# /
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/crack_yolov5l_results4/weights/best.pt'], source=/content/drive/MyDrive/crack_video/KakaoTalk_20220903_184107179.mp4, data=content/drive/MyDrive/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=content/drive/MyDrive/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: ipython not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /content/drive/MyDrive/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...
